# %% [markdown]
# # 使用回归方法预测行星尺寸
# 这是一个根据kaggle上行星数据集预测行星尺寸的数据预测分析笔记本。
# ## 0.引入包

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

import warnings
warnings.simplefilter(action='ignore',category=FutureWarning)

# %% [markdown]
# ## 1. 原始数据加载

# %%
df = pd.read_csv('./Asteroid.csv')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_15612\2552911804.py:1: DtypeWarning: Columns (0,10,15,16,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./Asteroid.csv')

# %% [markdown]
# ### 数据格式展示
# 下面展示数据的一些样例。

# %%
df.head()
# Out:
#       name         a         e          i          om           w         q  \
# 0    Ceres  2.769165  0.076009  10.594067   80.305532   73.597694  2.558684
# 1   Pallas  2.772466  0.230337  34.836234  173.080063  310.048857  2.133865
# 2     Juno  2.669150  0.256942  12.988919  169.852760  248.138626  1.983332
# 3    Vesta  2.361418  0.088721   7.141771  103.810804  150.728541  2.151909
# 4  Astraea  2.574249  0.191095   5.366988  141.576605  358.687607  2.082324
#
#          ad     per_y  data_arc  ...     UB  IR  spec_B spec_T     G     moid  \
# 0  2.979647  4.608202    8822.0  ...  0.426 NaN       C      G  0.12  1.59478
# 1  3.411067  4.616444   72318.0  ...  0.284 NaN       B      B  0.11  1.23324
# 2  3.354967  4.360814   72684.0  ...  0.433 NaN      Sk      S  0.32  1.03454
# 3  2.570926  3.628837   24288.0  ...  0.492 NaN       V      V  0.32  1.13948
# 4  3.066174  4.130323   63507.0  ...  0.411 NaN       S      S   NaN  1.09589
#
#   class         n          per          ma
# 0   MBA  0.213885  1683.145708   77.372096
# 1   MBA  0.213503  1686.155999   59.699133
# 2   MBA  0.226019  1592.787285   34.925016
# 3   MBA  0.271609  1325.432765   95.861936
# 4   MBA  0.238632  1508.600458  282.366289
#
# [5 rows x 31 columns]

# %% [markdown]
# ### 数据的列展示

# %%
df.columns
# Out:
# Index(['name', 'a', 'e', 'i', 'om', 'w', 'q', 'ad', 'per_y', 'data_arc',
#        'condition_code', 'n_obs_used', 'H', 'neo', 'pha', 'diameter', 'extent',
#        'albedo', 'rot_per', 'GM', 'BV', 'UB', 'IR', 'spec_B', 'spec_T', 'G',
#        'moid', 'class', 'n', 'per', 'ma'],
#       dtype='object')

# %% [markdown]
# ### 展示缺失数据

# %%
missing= pd.concat([pd.isnull(df).sum(), 100 * pd.isnull(df).mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by=['count'])
# Out:
#                  count          %
# e                    0   0.000000
# i                    0   0.000000
# om                   0   0.000000
# w                    0   0.000000
# q                    0   0.000000
# class                0   0.000000
# n_obs_used           0   0.000000
# per_y                1   0.000119
# a                    2   0.000238
# n                    2   0.000238
# ad                   6   0.000715
# neo                  6   0.000715
# per                  6   0.000715
# ma                   8   0.000953
# condition_code     867   0.103249
# H                 2689   0.320228
# data_arc         15474   1.842770
# pha              16442   1.958048
# moid             16442   1.958048
# diameter        702078  83.609181
# albedo          703305  83.755302
# name            817747  97.383990
# rot_per         820918  97.761619
# spec_B          838048  99.801599
# BV              838693  99.878411
# spec_T          838734  99.883294
# UB              838735  99.883413
# G               839595  99.985829
# extent          839696  99.997856
# GM              839700  99.998333
# IR              839713  99.999881

# %% [markdown]
# ### 展示可以用于学习的总行数

# %%
valid_rows = df['diameter'].notnull().sum()
valid_rows
# Out:
# 137636

# %% [markdown]
# ### 删除diameter元素为空的行

# %%
df = df.dropna(axis=0,subset=['diameter'])

len(df.index)
# Out:
# 137636

# %% [markdown]
# ### 摘除无效数据之后的数据值

# %%
missing= pd.concat([pd.isnull(df).sum(), 100 * pd.isnull(df).mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by=['count'])
# Out:
#                  count          %
# diameter             0   0.000000
# n                    0   0.000000
# class                0   0.000000
# moid                 0   0.000000
# per                  0   0.000000
# pha                  0   0.000000
# neo                  0   0.000000
# n_obs_used           0   0.000000
# condition_code       0   0.000000
# ma                   0   0.000000
# per_y                0   0.000000
# ad                   0   0.000000
# q                    0   0.000000
# w                    0   0.000000
# om                   0   0.000000
# a                    0   0.000000
# e                    0   0.000000
# i                    0   0.000000
# data_arc           138   0.100264
# H                  747   0.542736
# albedo            1230   0.893662
# name            122512  89.011596
# rot_per         126448  91.871313
# spec_B          136266  99.004621
# BV              136631  99.269813
# spec_T          136671  99.298875
# UB              136671  99.298875
# G               137517  99.913540
# extent          137620  99.988375
# GM              137622  99.989828
# IR              137635  99.999273

# %% [markdown]
# ### 继续摘除无效的原始数据

# %%
drop_list = ['H','albedo','name','rot_per','spec_B',
             'BV','spec_T','UB','G',
             'extent','GM','IR']
df.drop(drop_list, axis=1, inplace=True)
len(df.columns)
# Out:
# 19

# %% [markdown]
# ### 得到最终需要处理的数据组

# %%
df.dtypes
# Out:
# a                 float64
# e                 float64
# i                 float64
# om                float64
# w                 float64
# q                 float64
# ad                float64
# per_y             float64
# data_arc          float64
# condition_code     object
# n_obs_used          int64
# neo                object
# pha                object
# diameter           object
# moid              float64
# class              object
# n                 float64
# per               float64
# ma                float64
# dtype: object

# %% [markdown]
# ## 2.特征工程

# %% [markdown]
# ### 对`object`对象进行特征工程

# %%
df.select_dtypes('object').tail()
# Out:
#        condition_code neo pha diameter class
# 797860              1   N   N    3.793   MBA
# 798077              2   N   N    2.696   MBA
# 798189              1   N   N    2.917   MBA
# 799752              2   N   N    3.271   MBA
# 810375              3   N   N      1.6   MBA

# %%
# 处理diameter
# 由于原始数据出现有一行格式不统一，在转换的时候需要重新处理这一行的数据，便于运用pd的to_numeric函数
df.at[15,'diameter'] = 226
df['diameter'] = pd.to_numeric(df['diameter'])

# %%
# 处理condition_code
# 下面将这个数据段的内容读取出来换成唯一的数据值
df['condition_code'] = df['condition_code'].astype('int64')

df.condition_code.unique()
# Out:
# array([0, 1, 3, 2, 4, 5, 9, 7, 6, 8], dtype=int64)

# %%
# 处理neo 原始只有N和Y两组
df.neo.unique()
df['neo'].value_counts()
# Out:
# neo
# N    136786
# Y       850
# Name: count, dtype: int64

# %%
# 处理pha，原始只有N和Y两组
df.pha.unique()
df['pha'].value_counts()
# Out:
# pha
# N    137415
# Y       221
# Name: count, dtype: int64

# %%
df['class'].unique()
df['class'].value_counts()
# Out:
# class
# MBA    126390
# OMB      7510
# TJN      1874
# IMB       588
# APO       486
# MCA       355
# AMO       269
# ATE        95
# CEN        49
# TNO        13
# AST         7
# Name: count, dtype: int64

# %% [markdown]
# ### 展示整数特征
# 主要消除非正常类型对机器学习的影响。

# %%
df.select_dtypes('int64')
# Out:
#         condition_code  n_obs_used
# 0                    0        1002
# 1                    0        8490
# 2                    0        7104
# 3                    0        9325
# 4                    0        2916
# ...                ...         ...
# 797860               1          50
# 798077               2          33
# 798189               1          47
# 799752               2          27
# 810375               3          25
#
# [137636 rows x 2 columns]

# %% [markdown]
# ### 展示浮点数特征
# 主要消除正常类型对机器学习的影响。

# %%
df.select_dtypes('float64')
# Out:
#                a         e          i          om           w         q  \
# 0       2.769165  0.076009  10.594067   80.305532   73.597694  2.558684
# 1       2.772466  0.230337  34.836234  173.080063  310.048857  2.133865
# 2       2.669150  0.256942  12.988919  169.852760  248.138626  1.983332
# 3       2.361418  0.088721   7.141771  103.810804  150.728541  2.151909
# 4       2.574249  0.191095   5.366988  141.576605  358.687607  2.082324
# ...          ...       ...        ...         ...         ...       ...
# 797860  3.171225  0.159119  27.098625  309.036573   19.746812  2.666623
# 798077  2.548410  0.076071  11.593237  246.298656  170.090810  2.354549
# 798189  3.146246  0.220559  17.966646  137.981403  180.898833  2.452313
# 799752  3.051336  0.287449  14.456779  343.917822  342.614839  2.174231
# 810375  2.417477  0.109001   4.525668  148.244819   31.949854  2.153970
#
#               ad     per_y  data_arc  diameter     moid         n  \
# 0       2.979647  4.608202    8822.0   939.400  1.59478  0.213885
# 1       3.411067  4.616444   72318.0   545.000  1.23324  0.213503
# 2       3.354967  4.360814   72684.0   246.596  1.03454  0.226019
# 3       2.570926  3.628837   24288.0   525.400  1.13948  0.271609
# 4       3.066174  4.130323   63507.0   106.699  1.09589  0.238632
# ...          ...       ...       ...       ...      ...       ...
# 797860  3.675826  5.647402    2373.0     3.793  1.66301  0.174527
# 798077  2.742270  4.068291    3297.0     2.696  1.36733  0.242270
# 798189  3.840180  5.580811    2839.0     2.917  1.43837  0.176610
# 799752  3.928440  5.330196    2208.0     3.271  1.16684  0.184914
# 810375  2.680984  3.758822    3458.0     1.600  1.15942  0.262217
#
#                 per          ma
# 0       1683.145708   77.372096
# 1       1686.155999   59.699133
# 2       1592.787285   34.925016
# 3       1325.432765   95.861936
# 4       1508.600458  282.366289
# ...             ...         ...
# 797860  2062.713583  164.999439
# 798077  1485.943371  145.319581
# 798189  2038.391053  174.609920
# 799752  1946.853973  175.708508
# 810375  1372.909600  170.888415
#
# [137636 rows x 14 columns]

# %% [markdown]
# ### 参数分布
# 使用pd的`df`内置的函数`hist`对于数据中的各个表单项目进行绘制

# %%
df.hist(figsize=(20,10))
plt.show()

# %% [markdown]
# 使用`seaborn`库的箱线图绘制方法,对`DataFrame`中的`data_arc`列进行可视化,绘制出箱线图。
#
# 箱线图能直观地显示出这一列数据的四分位数范围、上下限范围和异常值,用于快速理解该列数据的分布情况。

# %%
sns.boxenplot(df['data_arc'])
# Out:
# <Axes: >

# %% [markdown]
# 用数据的中位数来补全那些缺失的数据。

# %%
df['data_arc'] = df['data_arc'].fillna(df['data_arc'].median())

# %% [markdown]
# 最终得到整数和浮点数的特征工程后的结果。

# %%
df.describe().T
# Out:
#                    count         mean          std         min          25%  \
# a               137636.0     2.814613     1.522740    0.626226     2.536714
# e               137636.0     0.145485     0.077573    0.000489     0.089623
# i               137636.0    10.349182     6.835111    0.021855     5.120506
# om              137636.0   169.827629   102.713052    0.000738    82.334880
# w               137636.0   181.904551   103.556464    0.004466    91.947943
# q               137636.0     2.402609     0.516169    0.081882     2.068948
# ad              137636.0     3.226618     2.896374    0.999956     2.864438
# per_y           137636.0     4.884248    25.532565    0.495569     4.040317
# data_arc        137636.0  8968.417086  6162.243453    1.000000  6292.000000
# condition_code  137636.0     0.485207     1.966078    0.000000     0.000000
# n_obs_used      137636.0   675.027740   595.935104    5.000000   215.000000
# diameter        137636.0     5.483228     9.385735    0.002500     2.770000
# moid            137636.0     1.420145     0.512241    0.000166     1.082523
# n               137636.0     0.219640     0.056980    0.000128     0.181231
# per             137636.0  1783.971577  9325.769218  181.006674  1475.725941
# ma              137636.0   183.116785   103.411497    0.000517    94.301261
#
#                         50%          75%           max
# a                  2.750859     3.092537  3.891460e+02
# e                  0.138543     0.191141  9.843482e-01
# i                  9.389963    13.738588  1.703236e+02
# om               160.438430   256.268387  3.599909e+02
# w                183.669900   271.762261  3.599952e+02
# q                  2.363897     2.685811  4.046567e+01
# ad                 3.167516     3.468608  7.722011e+02
# per_y              4.562581     5.438518  7.676743e+03
# data_arc        7572.000000  9726.000000  7.268400e+04
# condition_code     0.000000     0.000000  9.000000e+00
# n_obs_used       496.000000   984.000000  9.325000e+03
# diameter           3.956000     5.742000  9.394000e+02
# moid               1.384935     1.699385  3.950700e+01
# n                  0.216024     0.243948  1.988877e+00
# per             1666.482802  1986.418660  2.803930e+06
# ma               186.826667   271.468299  3.600000e+02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 137636 entries, 0 to 810375
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   a               137636 non-null  float64
#  1   e               137636 non-null  float64
#  2   i               137636 non-null  float64
#  3   om              137636 non-null  float64
#  4   w               137636 non-null  float64
#  5   q               137636 non-null  float64
#  6   ad              137636 non-null  float64
#  7   per_y           137636 non-null  float64
#  8   data_arc        137636 non-null  float64
#  9   condition_code  137636 non-null  int64
#  10  n_obs_used      137636 non-null  int64
#  11  neo             137636 non-null  object
#  12  pha             137636 non-null  object
#  13  diameter        137636 non-null  float64
#  14  moid            137636 non-null  float64
#  15  class           137636 non-null  object
#  16  n               137636 non-null  float64
#  17  per             137636 non-null  float64
#  18  ma              137636 non-null  float64
# dtypes: float64(14), int64(2), object(3)
# memory usage: 25.0+ MB

# %%
data_type = df.dtypes
data_type[(data_type=='object')|(data_type=='category')].index.tolist()
# Out:
# ['neo', 'pha', 'class']

# %% [markdown]
# 由于`neo`和`pha`对于实际的回归没有用处，选择丢弃这两个特征。

# %%
drop_list = ['neo','pha']
df.drop(drop_list,axis=1,inplace=True)

# %% [markdown]
# 下面针对`class`属性做进一步的研究。

# %%
df['class'] = df['class'].astype('category')
df['class'].dtypes
# Out:
# CategoricalDtype(categories=['AMO', 'APO', 'AST', 'ATE', 'CEN', 'IMB', 'MBA', 'MCA',
#                   'OMB', 'TJN', 'TNO'],
# , ordered=False)

# %%
sns.set_palette('inferno',11)

# %% [markdown]
# 展示不同`class`对小行星尺寸的影响。

# %%
sns.boxplot(x='class',y='diameter',data=df)
plt.yscale('log')

# %%
df['diameter'].describe()
# Out:
# count    137636.000000
# mean          5.483228
# std           9.385735
# min           0.002500
# 25%           2.770000
# 50%           3.956000
# 75%           5.742000
# max         939.400000
# Name: diameter, dtype: float64

# %% [markdown]
# 从`class`中`diameter`的分布看对应的`diameter`影响

# %%
class_group = df.groupby('class').agg({
    'diameter':['mean','median','min','max','std','var','count']
})
print(class_group)
# Out:
#          diameter
#              mean   median     min      max         std           var   count
# class
# AMO      1.766591   1.0450  0.0880   37.675    2.971932      8.832382     269
# APO      0.958425   0.6025  0.0025    8.480    1.097541      1.204597     486
# AST     14.283429  16.4000  2.6560   32.492   10.028549    100.571796       7
# ATE      0.630716   0.3700  0.0230    3.879    0.702853      0.494002      95
# CEN     52.473245  28.0000  0.8900  302.000   63.978581   4093.258785      49
# IMB      2.288675   1.7460  0.7420   11.506    1.470614      2.162706     588
# MBA      5.076341   3.8340  0.6000  939.400    8.277078     68.510018  126390
# MCA      3.411217   2.5570  0.5870   42.870    3.512911     12.340547     355
# OMB      8.783017   6.3565  0.3470  254.000   12.023403    144.562224    7510
# TJN     20.771467  15.4710  4.5620  225.000   16.487683    271.843695    1874
# TNO    151.986154  46.4000  6.4200  900.000  243.813592  59445.067426      13

# %% [markdown]
# `Condition Code`部分

# %%
sns.boxplot(x='condition_code', y='diameter', data=df)
plt.title('Diameter by Condition Code')
plt.yscale('log');

# %%
df.columns
# Out:
# Index(['a', 'e', 'i', 'om', 'w', 'q', 'ad', 'per_y', 'data_arc',
#        'condition_code', 'n_obs_used', 'diameter', 'moid', 'class', 'n', 'per',
#        'ma'],
#       dtype='object')

# %%
df.drop('condition_code',axis=1,inplace=True)
# df.drop('class',axis=1,inplace=True)

# %% [markdown]
# 研究数值特征之间的关系。(problem here)

# %%
df.drop('per_y',axis=1,inplace=True)
df.drop('moid',axis=1,inplace=True)

# %%
df.select_dtypes(include=['object']).head().T
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4]
# Index: []

# %%
df = pd.get_dummies(df,columns=['class'])

# %%
df.columns
# Out:
# Index(['a', 'e', 'i', 'om', 'w', 'q', 'ad', 'data_arc', 'n_obs_used',
#        'diameter', 'n', 'per', 'ma', 'class_AMO', 'class_APO', 'class_AST',
#        'class_ATE', 'class_CEN', 'class_IMB', 'class_MBA', 'class_MCA',
#        'class_OMB', 'class_TJN', 'class_TNO'],
#       dtype='object')

# %% [markdown]
# ## 3.训练前准备工作
# ### 划分训练集和测试集

# %%
from sklearn.model_selection import train_test_split
predictors = df.drop('diameter',axis=1)
target =  df['diameter']
X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.head()
# Out:
#                a         e          i          om           w         q  \
# 148020  2.726194  0.266986   8.078396   94.580422  291.214105  1.998338
# 241053  2.771711  0.079738   5.065503   49.562697  297.001221  2.550701
# 625000  3.210080  0.083664   3.653610  141.677454  309.154612  2.941511
# 304501  2.978885  0.033621   3.364579  103.027400  227.734228  2.878731
# 59497   2.470771  0.099896  24.383685  201.171239  331.721958  2.223951
#
#               ad  data_arc  n_obs_used         n  ...  class_APO  class_AST  \
# 148020  3.454050    7940.0         341  0.218962  ...      False      False
# 241053  2.992720    9339.0         291  0.213591  ...      False      False
# 625000  3.478649       1.0          13  0.171368  ...      False      False
# 304501  3.079038    5479.0         100  0.191701  ...      False      False
# 59497   2.717592    7522.0        1128  0.253779  ...      False      False
#
#         class_ATE  class_CEN  class_IMB  class_MBA  class_MCA  class_OMB  \
# 148020      False      False      False       True      False      False
# 241053      False      False      False       True      False      False
# 625000      False      False      False      False      False       True
# 304501      False      False      False       True      False      False
# 59497       False      False      False       True      False      False
#
#         class_TJN  class_TNO
# 148020      False      False
# 241053      False      False
# 625000      False      False
# 304501      False      False
# 59497       False      False
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 数据正则化

# %%
from sklearn import preprocessing

std_scaler = preprocessing.StandardScaler().fit(X_train)

def scaler(X):
    x_norm_arr = std_scaler.fit_transform(X)
    return pd.DataFrame(x_norm_arr,columns=X.columns,index=X.index)

X_train_norm = scaler(X_train)
X_test_norm =  scaler(X_test)

def inverse_scaler(X):
    x_norm_arr= std_scaler.inverse_transform(X)
    return pd.DataFrame(x_norm_arr, columns=X.columns, index = X.index)

# %% [markdown]
# **Trying different regressions and ranking them according to their R2 score.**
# **Algorithms used:** Linear Regression, Elastic Net, k-Nearest Neighbours, Decision Tree, Random Forest, SVM, Neural Network and XGBoost.

# %%
from sklearn.metrics import r2_score
import seaborn as sns

def plot(prediction):
    fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(20,7)) 
    sns.distplot(Y_test.values,label='test values', ax=ax1)
    sns.distplot(prediction ,label='prediction', ax=ax1)
    ax1.set_xlabel('Distribution plot')
    ax2.scatter(Y_test,prediction, c='orange',label='predictions')
    ax2.plot(Y_test,Y_test,c='blue',label='y=x')
    ax2.set_xlabel('test value')
    ax2.set_ylabel('estimated $\log(radius)$')
    ax1.legend()
    ax2.legend()
    ax2.axis('scaled') #same x y scale
def score(prediction):
    score = r2_score(prediction,Y_test)
    return score
def announce(score):
    print('The R^2 score achieved using this regression is:', round(score,3))
algorithms = []
scores = []

# %% [markdown]
# Linear Regression

# %%
#Defining the model
from sklearn.linear_model import SGDRegressor
lr = SGDRegressor(max_iter=10, tol=1e-3,learning_rate='optimal', eta0=0.001)

# 进行训练，并在每轮迭代后打印参数
n_epochs = 10  # 设定迭代轮数
for epoch in range(n_epochs):
    lr.fit(X_train, Y_train)
    # y_pred=X_train.dot(lr.coef_.T)+lr.intercept_
    y_pred = lr.predict(X_train) # 计算预测值
    loss = np.sum((Y_train-y_pred)**2/X_train.shape[0])  # 计算均方误差损失
    print(loss)
    # print(f"Epoch {epoch+1}, Loss: {loss}")

    # # 获取模型参数
    # coef = lr.coef_
    # intercept = lr.intercept_
    
    # # 打印参数
    # print(f"Epoch {epoch + 1}: Coefficients = {coef}, Intercept = {intercept}")

# 最终模型参数
final_coef = lr.coef_
final_intercept = lr.intercept_
print(f"Final Coefficients = {final_coef}, Final Intercept = {final_intercept}")

###Predicting
Y_pred_lr = lr.predict(X_test)

###Scoring
score_lr = score(Y_pred_lr)
announce(score_lr)

algorithms.append('LR')
scores.append(score_lr)

plot(Y_pred_lr)
# Out:
# d:\cs188\envs\MLC\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 3.9437843548571984e+34
# d:\cs188\envs\MLC\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 2.1013835348090217e+36
# d:\cs188\envs\MLC\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 2.7987883239322215e+36
# d:\cs188\envs\MLC\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 6.855040027856395e+36
# d:\cs188\envs\MLC\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 1.2561304336670932e+37
# d:\cs188\envs\MLC\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 2.8590942746949345e+36
# d:\cs188\envs\MLC\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 2.656800452960531e+36
# d:\cs188\envs\MLC\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 7.224952052270944e+35
# d:\cs188\envs\MLC\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# 2.952384971115299e+36
# d:\cs188\envs\MLC\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# C:\Users\dell\AppData\Local\Temp\ipykernel_15612\3642307910.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test.values,label='test values', ax=ax1)
# C:\Users\dell\AppData\Local\Temp\ipykernel_15612\3642307910.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(prediction ,label='prediction', ax=ax1)
# 2.687022390923342e+35
# Final Coefficients = [-2.89296440e+13 -1.67931355e+12  4.89418142e+13 -7.81176561e+13
#  -1.16522373e+13 -2.59817575e+13 -3.18775306e+13 -3.55715305e+13
#   2.72995453e+13 -4.56318805e+11  3.73869770e+13 -1.17413938e+14
#  -4.71835504e+11  5.26278062e+11 -3.62950387e+10 -3.26655349e+11
#  -1.81475194e+11  4.89983023e+11 -6.79144778e+12  4.35973102e+11
#   3.99245426e+11 -7.62195814e+11 -5.44425581e+10], Final Intercept = [-5.95656252e+14]
# The R^2 score achieved using this regression is: -1.591

# %% [markdown]
# Elastic Net Regression

# %%
### Defining the Model
from sklearn.linear_model import ElasticNetCV
enet = ElasticNetCV(cv=9,max_iter=10000)

### Training
enet.fit(X_train_norm,np.ravel(Y_train))

### Predicting
Y_pred_enet = enet.predict(X_test_norm)

###Scoring
score_enet = score(Y_pred_enet)
announce(score_enet)

algorithms.append('eNet')
scores.append(score_enet)

plot(Y_pred_enet)
# Out:
# The R^2 score achieved using this regression is: -1.386
# C:\Users\dell\AppData\Local\Temp\ipykernel_15612\3642307910.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test.values,label='test values', ax=ax1)
# C:\Users\dell\AppData\Local\Temp\ipykernel_15612\3642307910.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(prediction ,label='prediction', ax=ax1)

# %% [markdown]
# k-Nearest Neighbours regression:

# %%
### Defining the Model

from sklearn.neighbors import KNeighborsRegressor

##For weighted metric, more accurate but longer calculation
#weights = X_train_norm.corrwith(Y_train).abs()
#neigh = KNeighborsRegressor(n_neighbors=3, metric_params={'w' : weights.values}, metric='wminkowski')

neigh = KNeighborsRegressor(n_neighbors=3)

### Training
neigh.fit(X_train_norm,Y_train)

### Predicting 
Y_pred_neigh = neigh.predict(X_test_norm)

### Scoring
score_neigh=score(Y_pred_neigh)
announce(score_neigh)

algorithms.append('k-NN')
scores.append(score_neigh)

plot(Y_pred_neigh)
# Out:
# The R^2 score achieved using this regression is: -0.325
# C:\Users\dell\AppData\Local\Temp\ipykernel_15612\3642307910.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test.values,label='test values', ax=ax1)
# C:\Users\dell\AppData\Local\Temp\ipykernel_15612\3642307910.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(prediction ,label='prediction', ax=ax1)

# %% [markdown]
# Decision Tree Regression

# %%
### Defining the model
from sklearn import tree
decTree = tree.DecisionTreeRegressor()

### Training
decTree = decTree.fit(X_train_norm,Y_train)

### Predicting
Y_pred_tree = decTree.predict(X_test_norm)

### Scoring
score_tree = score(Y_pred_tree)
announce(score_tree)

algorithms.append('DTree')
scores.append(score_tree)

plot(Y_pred_tree)
# Out:
# The R^2 score achieved using this regression is: 0.123
# C:\Users\dell\AppData\Local\Temp\ipykernel_15612\3642307910.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test.values,label='test values', ax=ax1)
# C:\Users\dell\AppData\Local\Temp\ipykernel_15612\3642307910.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(prediction ,label='prediction', ax=ax1)

# %% [markdown]
# Random Forest Regression

# %%
### Defining the model
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor(max_depth=32, n_estimators=50)

### Training 
forest.fit(X_train_norm,np.ravel(Y_train))

###Predicting
Y_pred_forest = forest.predict(X_test_norm)

### Scoring
score_forest = score(Y_pred_forest)
announce(score_forest)

algorithms.append('RForest')
scores.append(score_forest)

plot(Y_pred_forest)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 2
#       1 ### Defining the model
# ----> 2 from sklearn.ensemble import RandomForestRegressor
#       3 forest = RandomForestRegressor(max_depth=32, n_estimators=50)
#       5 ### Training
#
# File d:\cs188\envs\MLC\lib\site-packages\sklearn\ensemble\__init__.py:15
#       7 from ._forest import (
#       8     ExtraTreesClassifier,
#       9     ExtraTreesRegressor,
#    (...)
#      12     RandomTreesEmbedding,
#      13 )
#      14 from ._gb import GradientBoostingClassifier, GradientBoostingRegressor
# ---> 15 from ._hist_gradient_boosting.gradient_boosting import (
#      16     HistGradientBoostingClassifier,
#      17     HistGradientBoostingRegressor,
#      18 )
#      19 from ._iforest import IsolationForest
#      20 from ._stacking import StackingClassifier, StackingRegressor
#
# File d:\cs188\envs\MLC\lib\site-packages\sklearn\ensemble\_hist_gradient_boosting\gradient_boosting.py:41
#      34 from ...utils.multiclass import check_classification_targets
#      35 from ...utils.validation import (
#      36     _check_monotonic_cst,
#      37     _check_sample_weight,
#      38     check_consistent_length,
#      39     check_is_fitted,
#      40 )
# ---> 41 from ._gradient_boosting import _update_raw_predictions
#      42 from .binning import _BinMapper
#      43 from .common import G_H_DTYPE, X_DTYPE, Y_DTYPE
#
# File <frozen importlib._bootstrap>:398, in parent(self)
#
# KeyboardInterrupt:

# %% [markdown]
# Support Vector Machine regression: (too slow when n_samples > 30000)

# %%
### Defining the model
from sklearn import svm
svmreg = svm.SVR()

### Training
svmreg.fit(X_train_norm,np.ravel(Y_train))

### Predicting
Y_pred_svm = svmreg.predict(X_test_norm)

### Scoring
score_svm = score(Y_pred_svm)
announce(score_svm)

algorithms.append('SVM')
scores.append(score_svm)

plot(Y_pred_svm)
# Out:
# The R^2 score achieved using this regression is: -2.813
# C:\Users\dell\AppData\Local\Temp\ipykernel_4104\3642307910.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test.values,label='test values', ax=ax1)
# C:\Users\dell\AppData\Local\Temp\ipykernel_4104\3642307910.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(prediction ,label='prediction', ax=ax1)

# %% [markdown]
# XGBoost regression:

# %%
### Defining the model
import xgboost as xgb 
xgReg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, 
                         learning_rate = 0.08 ,
                max_depth = 4, n_estimators = 500)

### Training
xgReg.fit(X_train_norm,Y_train)

### Predicting
Y_pred_xgb = xgReg.predict(X_test_norm)

### Scoring
score_xgb = score(Y_pred_xgb)
announce(score_xgb)

algorithms.append('XGB')
scores.append(score_xgb)
# Out:
# The R^2 score achieved using this regression is: -0.234

# %%
plot(Y_pred_xgb)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4104\3642307910.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test.values,label='test values', ax=ax1)
# C:\Users\dell\AppData\Local\Temp\ipykernel_4104\3642307910.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(prediction ,label='prediction', ax=ax1)

# %%
# One bonus of using xgboost is being able to 
# simply see how important the different features where when creating the learners.

fig, ax = plt.subplots(figsize=(10,10))
xgb.plot_importance(xgReg, height=0.5, ax=ax, importance_type='weight')
plt.show()
